# %%
# !pip install selenium
# !pip install webdriver-manager
# Out:
# Requirement already satisfied: selenium in c:\users\khadija\appdata\local\programs\python\python311\lib\site-packages (4.15.2)
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in c:\users\khadija\appdata\local\programs\python\python311\lib\site-packages (from selenium) (2.1.0)
# Requirement already satisfied: trio~=0.17 in c:\users\khadija\appdata\local\programs\python\python311\lib\site-packages (from selenium) (0.23.1)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\khadija\appdata\local\programs\python\python311\lib\site-packages (from selenium) (0.11.1)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\khadija\appdata\local\programs\python\python311\lib\site-packages (from selenium) (2023.7.22)
# Requirement already satisfied: attrs>=20.1.0 in c:\users\khadija\appdata\local\programs\python\python311\lib\site-packages (from trio~=0.17->selenium) (23.1.0)
# Requirement already satisfied: sortedcontainers in c:\users\khadija\appdata\local\programs\python\python311\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\khadija\appdata\local\programs\python\python311\lib\site-packages (from trio~=0.17->selenium) (2.10)
# Requirement already satisfied: outcome in c:\users\khadija\appdata\local\programs\python\python311\lib\site-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\khadija\appdata\local\programs\python\python311\lib\site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\khadija\appdata\local\programs\python\python311\lib\site-packages (from trio~=0.17->selenium) (1.16.0)
# Requirement already satisfied: wsproto>=0.14 in c:\users\khadija\appdata\local\programs\python\python311\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\users\khadija\appdata\local\programs\python\python311\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\khadija\appdata\local\programs\python\python311\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\khadija\appdata\local\programs\python\python311\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.9.0)
# Requirement already satisfied: webdriver-manager in c:\users\khadija\appdata\local\programs\python\python311\lib\site-packages (4.0.1)
# Requirement already satisfied: requests in c:\users\khadija\appdata\local\programs\python\python311\lib\site-packages (from webdriver-manager) (2.31.0)
# Requirement already satisfied: python-dotenv in c:\users\khadija\appdata\local\programs\python\python311\lib\site-packages (from webdriver-manager) (1.0.0)
# Requirement already satisfied: packaging in c:\users\khadija\appdata\roaming\python\python311\site-packages (from webdriver-manager) (23.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\khadija\appdata\local\programs\python\python311\lib\site-packages (from requests->webdriver-manager) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\khadija\appdata\local\programs\python\python311\lib\site-packages (from requests->webdriver-manager) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\khadija\appdata\local\programs\python\python311\lib\site-packages (from requests->webdriver-manager) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\khadija\appdata\local\programs\python\python311\lib\site-packages (from requests->webdriver-manager) (2023.7.22)
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\khadija\appdata\local\programs\python\python311\lib\site-packages (3.8.1)
# Requirement already satisfied: click in c:\users\khadija\appdata\local\programs\python\python311\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\khadija\appdata\local\programs\python\python311\lib\site-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\khadija\appdata\local\programs\python\python311\lib\site-packages (from nltk) (2023.10.3)
# Requirement already satisfied: tqdm in c:\users\khadija\appdata\local\programs\python\python311\lib\site-packages (from nltk) (4.66.1)
# Requirement already satisfied: colorama in c:\users\khadija\appdata\roaming\python\python311\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#Importing the necessary libraries

from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
import time
import pandas as pd
import numpy as np

# %%
from selenium import webdriver
from selenium.webdriver.firefox.service import Service as FirefoxService
from webdriver_manager.firefox import GeckoDriverManager

driver = webdriver.Firefox(service=FirefoxService(GeckoDriverManager().install()))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\Khadija\Downloads\i220560_PAI_PROJECT\Web_scraping.ipynb Cell 4 line 5
#       <a href='vscode-notebook-cell:/c%3A/Users/Khadija/Downloads/i220560_PAI_PROJECT/Web_scraping.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> from selenium.webdriver.firefox.service import Service as FirefoxService
#       <a href='vscode-notebook-cell:/c%3A/Users/Khadija/Downloads/i220560_PAI_PROJECT/Web_scraping.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a> from webdriver_manager.firefox import GeckoDriverManager
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Khadija/Downloads/i220560_PAI_PROJECT/Web_scraping.ipynb#W3sZmlsZQ%3D%3D?line=4'>5</a> driver = webdriver.Firefox(service=FirefoxService(GeckoDriverManager().install()))
#
# File c:\Users\Khadija\AppData\Local\Programs\Python\Python311\Lib\site-packages\webdriver_manager\firefox.py:39, in GeckoDriverManager.install(self)
#      38 def install(self) -> str:
# ---> 39     driver_path = self._get_driver_binary_path(self.driver)
#      40     os.chmod(driver_path, 0o755)
#      41     return driver_path
#
# File c:\Users\Khadija\AppData\Local\Programs\Python\Python311\Lib\site-packages\webdriver_manager\core\manager.py:40, in DriverManager._get_driver_binary_path(self, driver)
#      37     return binary_path
#      39 os_type = self.get_os_type()
# ---> 40 file = self._download_manager.download_file(driver.get_driver_download_url(os_type))
#      41 binary_path = self._cache_manager.save_file_to_cache(driver, file)
#      42 return binary_path
#
# File c:\Users\Khadija\AppData\Local\Programs\Python\Python311\Lib\site-packages\webdriver_manager\core\download_manager.py:32, in WDMDownloadManager.download_file(self, url)
#      30 log(f"Driver downloading response is {response.status_code}")
#      31 file_name = self.extract_filename_from_url(url)
# ---> 32 return File(response, file_name)
#
# File c:\Users\Khadija\AppData\Local\Programs\Python\Python311\Lib\site-packages\webdriver_manager\core\file_manager.py:12, in File.__init__(self, stream, file_name)
#      11 def __init__(self, stream, file_name):
# ---> 12     self.content = stream.content
#      13     self.__stream = stream
#      14     self.file_name = file_name
#
# File c:\Users\Khadija\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\models.py:899, in Response.content(self)
#     897         self._content = None
#     898     else:
# --> 899         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     901 self._content_consumed = True
#     902 # don't need to release the connection; that's been handled by urllib3
#     903 # since we exhausted the data.
#
# File c:\Users\Khadija\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\models.py:816, in Response.iter_content.<locals>.generate()
#     814 if hasattr(self.raw, "stream"):
#     815     try:
# --> 816         yield from self.raw.stream(chunk_size, decode_content=True)
#     817     except ProtocolError as e:
#     818         raise ChunkedEncodingError(e)
#
# File c:\Users\Khadija\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\response.py:934, in HTTPResponse.stream(self, amt, decode_content)
#     932 else:
#     933     while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
# --> 934         data = self.read(amt=amt, decode_content=decode_content)
#     936         if data:
#     937             yield data
#
# File c:\Users\Khadija\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\response.py:877, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     874     if len(self._decoded_buffer) >= amt:
#     875         return self._decoded_buffer.get(amt)
# --> 877 data = self._raw_read(amt)
#     879 flush_decoder = amt is None or (amt != 0 and not data)
#     881 if not data and len(self._decoded_buffer) == 0:
#
# File c:\Users\Khadija\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\response.py:812, in HTTPResponse._raw_read(self, amt)
#     809 fp_closed = getattr(self._fp, "closed", False)
#     811 with self._error_catcher():
# --> 812     data = self._fp_read(amt) if not fp_closed else b""
#     813     if amt is not None and amt != 0 and not data:
#     814         # Platform-specific: Buggy versions of Python.
#     815         # Close the connection when no data is returned
#    (...)
#     820         # not properly close the connection in all cases. There is
#     821         # no harm in redundantly calling close.
#     822         self._fp.close()
#
# File c:\Users\Khadija\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\response.py:797, in HTTPResponse._fp_read(self, amt)
#     794     return buffer.getvalue()
#     795 else:
#     796     # StringIO doesn't like amt=None
# --> 797     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File c:\Users\Khadija\AppData\Local\Programs\Python\Python311\Lib\http\client.py:466, in HTTPResponse.read(self, amt)
#     463 if self.length is not None and amt > self.length:
#     464     # clip the read to the "end of response"
#     465     amt = self.length
# --> 466 s = self.fp.read(amt)
#     467 if not s and amt:
#     468     # Ideally, we would raise IncompleteRead if the content-length
#     469     # wasn't satisfied, but it might break compatibility.
#     470     self._close_conn()
#
# File c:\Users\Khadija\AppData\Local\Programs\Python\Python311\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File c:\Users\Khadija\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1274     if flags != 0:
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#    1280     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\Khadija\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1132 try:
#    1133     if buffer is not None:
# -> 1134         return self._sslobj.read(len, buffer)
#    1135     else:
#    1136         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service as ChromeService
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))

# %%
url = 'https://www.daraz.pk/'
driver.get(url)

# %%
search_bar = driver.find_element(By.XPATH, '/html/body/div[1]/div/div/div[1]/div/div/div[2]/div/div[2]/form/div/div[1]/input[1]')
search_bar.send_keys('mobile phone' + Keys.RETURN)

# %%
ad_grid = driver.find_element(By.XPATH, '/html/body/div[3]/div/div[3]/div/div/div[1]/div[2]')
ad_cards = ad_grid.find_elements(By.CLASS_NAME, 'gridItem--Yd0sa')

# %%
# ad_grid = driver.find_element(By.CSS_SELECTOR, 'box--ujueT')
title = []
ship_sat = []
seller = []
rating = []
total_rating = []
price = []
brand = []
box = []
ques = []
ram = []
img = []
ship = []
mall = []
links = {}
# i = ad_cards[0]
for i in ad_cards:
    b = i.find_element(By.CLASS_NAME, 'title--wFj93')
    a = b.find_element(By.TAG_NAME, 'a')
    link = a.get_attribute('href')

    point = 0
    c = i.find_element(By.CLASS_NAME, 'rateAndLoc--XWchq')
    d = c.find_elements(By.TAG_NAME, 'span')
    buff = []
    for j in d:
        buff.append(j.text)
    # print(buff)
    stat = buff[-1]
    # print('stat', stat)
    if stat == 'Free Shipping':
        ship.append(1000)
        point = 1000
    else:
        ship.append(0)

    e = i.find_element(By.CLASS_NAME, 'price--NVB62')
    f = e.find_element(By.TAG_NAME, 'span')
    pr = f.text
    pr = pr.split()
    pr = pr[1]
    pr = pr.replace(',', '')
    # print(pr)
    p = float(pr)
    # print('price', p)
    price.append(p)

    point = int(point)

    try:
        i.find_element(By.CSS_SELECTOR, '.ic-dynamic-badge.ic-dynamic-badge-lazMall.ic-dynamic-group-1')
        mall.append(5000)
    except:
        mall.append(0)

    # print(stat, a.text)
    links[a.text] = [link, point, p]

    temp = dict()
    temp['Name'] = []
    temp['Review text'] = []

    driver.execute_script(f"window.open('{link}','secondtab');")
    driver.switch_to.window(driver.window_handles[1]) 

    driver.execute_script("window.scrollTo(0, 500);")
    time.sleep(2)
    driver.execute_script("window.scrollTo(500, 800);")
    time.sleep(2)
    driver.execute_script("window.scrollTo(800, 1000);")
    time.sleep(2)
    driver.execute_script("window.scrollTo(1000, 2000);")
    time.sleep(4)
    driver.execute_script("window.scrollTo(2000, 3000);")
    time.sleep(4)
    driver.execute_script("window.scrollTo(3000, 4000);")
    time.sleep(4)
    driver.execute_script("window.scrollTo(4000, 5000);")
    time.sleep(4)
    driver.execute_script("window.scrollTo(5000, 6000);")
    time.sleep(4)
    driver.execute_script("window.scrollTo(6000, 7000);")
    time.sleep(4)
    driver.execute_script("window.scrollTo(7000, 8000);")

#     mod_rating = WebDriverWait(driver, 10).until(
#     EC.presence_of_element_located((By.CLASS_NAME, 'mod-rating'))
# )
    # mod_rating = find

    g = driver.find_element(By.CLASS_NAME, "review-info-rate")
    h = g.find_element(By.CLASS_NAME, 'score')
    rate = h.text
    rate = float(rate[0])
    rating.append(rate)
    print(rate)

    ttrt = driver.find_element(By.CLASS_NAME, 'rate-num')
    tt = ttrt.text.split()
    total_rating.append(tt[0])
    print(tt[0])

    spec = driver.find_element(By.CLASS_NAME, 'specification-keys')
    li = spec.find_elements(By.TAG_NAME, 'li')
    b = ''
    c =0
    for a in li:
        if c== 0:
            b = li.text
            brand.append(b)
            print(b)
        c+=1

    bx = driver.find_element(By.CSS_SELECTOR, '.html-content.box-content-html')
    print(bx.text)
    box.append(bx.text)

    sku = driver.find_elements(By.CSS_SELECTOR, '.sku-name.')
    rm = ''
    for r in sku:
        if r.text.isdigit():
            rm = r.text
            ram.append(rm)

    im = driver.find_element(By.CLASS_NAME, 'gallery-preview-panel__image')
    imm = im.get_attribute('src')
    img.append(imm.text)
    print(imm.text)
    # k = driver.find_element(By.CLASS_NAME, 'pdp-seller-info-pc')
    # l = k.find_elements(By.CLASS_NAME, 'info-content')
    # count = 0
    # sell = ''
    # shsat = ''
    # for j in l:
    #     if count ==0:
    #         sell = j.text
    #         sell = sell[-3:-1]
    #         # sell = sell[:-2]
    #     elif count == 1:
    #         shsat = j.text
    #         shsat = shsat[-3:-1]
    #     # print('newline')
    #     # print(j.text)
    #     count += 1
    # # print("sell", sell)
    # # print("Ship", shsat)
    # sell = float(sell)
    # shsat = float(shsat)
    # seller.append(sell)
    # ship_sat.append(shsat)

    # for page in range(0,3):
    try:
        reviews_container = driver.find_element(By.XPATH, '//*[@id="module_product_review"]/div/div/div[3]/div[1]')
    except NoSuchElementException:
        print('No Reviews')
        break
    reviews = reviews_container.find_elements(By.CLASS_NAME,'item')

    for i in range(len(reviews)):
        if reviews[i].find_element(By.CSS_SELECTOR, f"#module_product_review > div > div > div:nth-child(3) > div.mod-reviews > div:nth-child({i+1}) > div.item-content > div.content").text != '':
            temp['Name'].append(reviews[i].find_element(By.CLASS_NAME,'middle').find_element(By.TAG_NAME,'span').text[3:])
            temp['Review text'].append(reviews[i].find_element(By.CSS_SELECTOR, f"#module_product_review > div > div > div:nth-child(3) > div.mod-reviews > div:nth-child({i+1}) > div.item-content > div.content").text)



    rv = pd.DataFrame(temp)
    reviews.append(temp)

    driver.close()
    driver.switch_to.window(driver.window_handles[0]) 


# links
# ship
# ad_cards
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\Khadija\Downloads\i220560_PAI_PROJECT\Web_scraping.ipynb Cell 9 line 9
#      <a href='vscode-notebook-cell:/c%3A/Users/Khadija/Downloads/i220560_PAI_PROJECT/Web_scraping.ipynb#X11sZmlsZQ%3D%3D?line=90'>91</a> h = g.find_element(By.CLASS_NAME, 'score')
#      <a href='vscode-notebook-cell:/c%3A/Users/Khadija/Downloads/i220560_PAI_PROJECT/Web_scraping.ipynb#X11sZmlsZQ%3D%3D?line=91'>92</a> rate = h.text
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Khadija/Downloads/i220560_PAI_PROJECT/Web_scraping.ipynb#X11sZmlsZQ%3D%3D?line=92'>93</a> rate = float(rate[0].text)
#      <a href='vscode-notebook-cell:/c%3A/Users/Khadija/Downloads/i220560_PAI_PROJECT/Web_scraping.ipynb#X11sZmlsZQ%3D%3D?line=93'>94</a> rating.append(rate)
#      <a href='vscode-notebook-cell:/c%3A/Users/Khadija/Downloads/i220560_PAI_PROJECT/Web_scraping.ipynb#X11sZmlsZQ%3D%3D?line=94'>95</a> print(rate)
#
# AttributeError: 'str' object has no attribute 'text'

# %%
import time
import pandas as pd

driver.get(url)

temp = dict()
temp['Name'] = []
temp['Review text'] = []

driver.execute_script("window.scrollTo(0, 500);")
time.sleep(1)
driver.execute_script("window.scrollTo(500, 800);")
time.sleep(1)
driver.execute_script("window.scrollTo(800, 1000);")
time.sleep(2)
driver.execute_script("window.scrollTo(1000, 1300);")
time.sleep(2)
driver.execute_script("window.scrollTo(1300, 1600);")
time.sleep(1)

for page in range(0,3):
    try:
        reviews_container = driver.find_element(By.XPATH, '//*[@id="module_product_review"]/div/div/div[3]/div[1]')
    except NoSuchElementException:
        print('No Reviews')
        break
    reviews = reviews_container.find_elements(By.CLASS_NAME,'item')

    for i in range(len(reviews)):
        if reviews[i].find_element(By.CSS_SELECTOR, f"#module_product_review > div > div > div:nth-child(3) > div.mod-reviews > div:nth-child({i+1}) > div.item-content > div.content").text != '':
            temp['Name'].append(reviews[i].find_element(By.CLASS_NAME,'middle').find_element(By.TAG_NAME,'span').text[3:])
            temp['Review text'].append(reviews[i].find_element(By.CSS_SELECTOR, f"#module_product_review > div > div > div:nth-child(3) > div.mod-reviews > div:nth-child({i+1}) > div.item-content > div.content").text)

    try:
        if(page != 2):
            nxt_button = driver.find_element(By.XPATH, '//*[@id="module_product_review"]/div/div/div[3]/div[2]/div/button[2]')
            driver.execute_script("arguments[0].click();", nxt_button)
            time.sleep(5)
    except NoSuchElementException:
        print('No More Pages')
        break

reviews = pd.DataFrame(temp)

reviews

# %%
df = pd.DataFrame({
    'Name': title,
    'Rating': rating,
    'Total Rating': total_rating,
    'Price': price,
    'Brand': brand,
    'Questions': ques
})
# Write DataFrame to CSV
df.to_csv('product.csv', index=False)
reviews.to_csv('reviews.csv', index = False)
